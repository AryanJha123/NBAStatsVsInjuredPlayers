# %%
from nba_api.stats.endpoints import leaguegamelog
games = leaguegamelog.LeagueGameLog(player_or_team_abbreviation='T', season="2023-24", sorter="DATE") 
gdict = games.get_dict()    
game_id = gdict['resultSets'][0]['rowSet'][0][4]
games.get_data_frames()[0]
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        22023  1610612747               LAL     Los Angeles Lakers
# 1        22023  1610612743               DEN         Denver Nuggets
# 2        22023  1610612756               PHX           Phoenix Suns
# 3        22023  1610612744               GSW  Golden State Warriors
# 4        22023  1610612746               LAC            LA Clippers
# ...        ...         ...               ...                    ...
# 2455     22023  1610612764               WAS     Washington Wizards
# 2456     22023  1610612755               PHI     Philadelphia 76ers
# 2457     22023  1610612751               BKN          Brooklyn Nets
# 2458     22023  1610612739               CLE    Cleveland Cavaliers
# 2459     22023  1610612766               CHA      Charlotte Hornets
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  \
# 0     0022300061  2023-10-24    LAL @ DEN  L  240   41  ...    31   44   23
# 1     0022300061  2023-10-24  DEN vs. LAL  W  240   48  ...    33   42   29
# 2     0022300062  2023-10-24    PHX @ GSW  W  240   42  ...    43   60   23
# 3     0022300062  2023-10-24  GSW vs. PHX  L  240   36  ...    31   49   19
# 4     0022300074  2023-10-25  LAC vs. POR  W  240   47  ...    31   45   36
# ...          ...         ...          ... ..  ...  ...  ...   ...  ...  ...
# 2455  0022301186  2024-04-14    WAS @ BOS  L  240   49  ...    28   36   33
# 2456  0022301192  2024-04-14  PHI vs. BKN  W  240   41  ...    44   57   30
# 2457  0022301192  2024-04-14    BKN @ PHI  L  240   32  ...    38   42   19
# 2458  0022301187  2024-04-14  CLE vs. CHA  L  240   44  ...    31   43   30
# 2459  0022301187  2024-04-14    CHA @ CLE  W  240   46  ...    37   47   36
#
#       STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0       5    4   12  18  107         -12                1
# 1       9    6   12  15  119          12                1
# 2       5    7   19  22  108           4                1
# 3      11    6   11  23  104          -4                1
# 4      11    7   18  20  123          12                1
# ...   ...  ...  ...  ..  ...         ...              ...
# 2455    9    4   12  16  122         -10                1
# 2456    8    6   14  16  107          21                1
# 2457    8    6   13  14   86         -21                1
# 2458    4    1   14   8  110         -10                1
# 2459   10    9   10  11  120          10                1
#
# [2460 rows x 29 columns]

# %%
getting = True
game_ids=[]
i = 0 
while getting:
    try:
        if gdict['resultSets'][0]['rowSet'][i][3] == "Memphis Grizzlies":
            game_ids.append(gdict['resultSets'][0]['rowSet'][i][4])
        i += 1
    except:
        getting = False
print(game_ids)
# Out:
# ['0022300071', '0022300078', '0022300089', '0022300106', '0022300125', '0022300007', '0022300144', '0022300164', '0022300012', '0022300179', '0022300026', '0022300206', '0022300213', '0022300231', '0022300044', '0022300249', '0022300261', '0022300277', '0022300288', '0022301206', '0022301221', '0022300299', '0022300314', '0022300332', '0022300355', '0022300360', '0022300377', '0022300393', '0022300410', '0022300425', '0022300438', '0022300449', '0022300460', '0022300470', '0022300491', '0022300503', '0022300515', '0022300537', '0022300544', '0022300560', '0022300582', '0022300597', '0022300609', '0022300621', '0022300638', '0022300652', '0022300663', '0022300687', '0022300693', '0022300706', '0022300722', '0022300737', '0022300751', '0022300766', '0022300783', '0022300790', '0022300807', '0022300830', '0022300845', '0022300861', '0022300868', '0022300879', '0022300896', '0022300913', '0022300931', '0022300940', '0022300950', '0022300972', '0022300989', '0022301001', '0022301015', '0022301040', '0022301055', '0022301075', '0022301088', '0022301107', '0022301121', '0022301129', '0022301151', '0022301158', '0022301177', '0022301193']

# %%
u_game_ids = []
for i in game_ids:
    if i not in u_game_ids:
        u_game_ids.append(i)
print(len(u_game_ids))
# Out:
# 82

# %%
print(str(u_game_ids)[1:-1])
# Out:
# '0022300071', '0022300078', '0022300089', '0022300106', '0022300125', '0022300007', '0022300144', '0022300164', '0022300012', '0022300179', '0022300026', '0022300206', '0022300213', '0022300231', '0022300044', '0022300249', '0022300261', '0022300277', '0022300288', '0022301206', '0022301221', '0022300299', '0022300314', '0022300332', '0022300355', '0022300360', '0022300377', '0022300393', '0022300410', '0022300425', '0022300438', '0022300449', '0022300460', '0022300470', '0022300491', '0022300503', '0022300515', '0022300537', '0022300544', '0022300560', '0022300582', '0022300597', '0022300609', '0022300621', '0022300638', '0022300652', '0022300663', '0022300687', '0022300693', '0022300706', '0022300722', '0022300737', '0022300751', '0022300766', '0022300783', '0022300790', '0022300807', '0022300830', '0022300845', '0022300861', '0022300868', '0022300879', '0022300896', '0022300913', '0022300931', '0022300940', '0022300950', '0022300972', '0022300989', '0022301001', '0022301015', '0022301040', '0022301055', '0022301075', '0022301088', '0022301107', '0022301121', '0022301129', '0022301151', '0022301158', '0022301177', '0022301193'

# %%
f = open("game_ids.txt", "w")
f.write(str(u_game_ids)[1:-1])
f.close()
